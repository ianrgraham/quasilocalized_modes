# %%
import numpy as np
import sys
sys.path.insert(0,"../")
import hessian_calc as hc
import pandas as pd
import scipy.sparse as scsp
import scipy.sparse.linalg
from numba import njit
import glob
import matplotlib.pyplot as plt
import matplotlib as mpl
# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline
import gsd.hoomd
import gsd.fl

# %%
def get_r(pid):
    if pid == 0:
        r = 5/12
    else:
        r = 7/12
    return r

"""traj = dir + "traj.gsd"
df = pd.read_csv(dir+'log.dat', delimiter='\t')
df2 = df.iloc[9::10,:]
tmp = gsd.fl.open(name=traj, mode='rb')
print(tmp.nframes)
frames = tmp.nframes
tmp.close()
with gsd.hoomd.open(name=traj, mode='rb') as t:
    s = t[0]
    s2 = t[-1]"""
# Out:
# 'traj = dir + "traj.gsd"\ndf = pd.read_csv(dir+\'log.dat\', delimiter=\'\t\')\ndf2 = df.iloc[9::10,:]\ntmp = gsd.fl.open(name=traj, mode=\'rb\')\nprint(tmp.nframes)\nframes = tmp.nframes\ntmp.close()\nwith gsd.hoomd.open(name=traj, mode=\'rb\') as t:\n    s = t[0]\n    s2 = t[-1]'

# %%
@njit
def overlap_matrix(vecs):
    l = len(vecs)
    for i in np.arange(l):
        vecs[i] = vecs[i]/np.linalg.norm(vecs[i])
    olap = np.zeros((l,l))
    for i in np.arange(l):
        for j in np.arange(i+1, l):
            tmp = np.dot(vecs[i],vecs[j])
            olap[i,j] = tmp
            olap[j,i] = tmp
    return olap

@njit
def abs_overlap_matrix(vecs):
    l = len(vecs)
    for i in np.arange(l):
        vecs[i] = vecs[i]/np.linalg.norm(vecs[i])
    olap = np.zeros((l,l))
    for i in np.arange(l):
        for j in np.arange(i+1, l):
            tmp = np.abs(np.dot(vecs[i],vecs[j]))
            olap[i,j] = tmp
            olap[j,i] = tmp
    return olap

@njit
def particle_overlap_matrix(vecs):
    l = len(vecs)
    r = vecs[0].size//2
    nvecs = np.zeros((l,r))
    for i in np.arange(l):
        vecs[i] = vecs[i]/np.linalg.norm(vecs[i])
        for j in np.arange(r):
            nvecs[i,j] = np.linalg.norm(vecs[i,2*j:2*(j+1)])
    olap = np.zeros((l,l))
    for i in np.arange(l):
        for j in np.arange(i+1, l):
            tmp = np.dot(nvecs[i],nvecs[j])
            olap[i,j] = tmp
            olap[j,i] = tmp
    return olap

# %%
dir1 = "../../hoomd_test/final_data/"

# %%
dirs = glob.glob(dir1+"constPhi1.1_*/")

# %%
dirs
# Out:
# ['../../hoomd_test/final_data/constPhi1.1_N10000_seed32_maxStrain0.05_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed33_maxStrain0.05_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed30_maxStrain0.05_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed31_maxStrain0.05_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed34_maxStrain0.05_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed35_maxStrain0.05_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed36_maxStrain0.05_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed37_maxStrain0.05_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed38_maxStrain0.05_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed39_maxStrain0.05_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed23_maxStrain0.04_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed22_maxStrain0.04_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed20_maxStrain0.04_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed21_maxStrain0.04_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed10_maxStrain0.03_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed13_maxStrain0.03_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed11_maxStrain0.03_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed12_maxStrain0.03_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed0_maxStrain0.02_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed3_maxStrain0.02_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed2_maxStrain0.02_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed1_maxStrain0.02_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed43_maxStrain0.01_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed40_maxStrain0.01_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed41_maxStrain0.01_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed42_maxStrain0.01_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed44_maxStrain0.01_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed45_maxStrain0.01_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed46_maxStrain0.01_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed47_maxStrain0.01_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed4_maxStrain0.02_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed5_maxStrain0.02_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed6_maxStrain0.02_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed48_maxStrain0.01_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed49_maxStrain0.01_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed7_maxStrain0.02_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed14_maxStrain0.03_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed15_maxStrain0.03_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed16_maxStrain0.03_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed17_maxStrain0.03_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed8_maxStrain0.02_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed9_maxStrain0.02_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed24_maxStrain0.04_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed25_maxStrain0.04_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed26_maxStrain0.04_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed27_maxStrain0.04_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed18_maxStrain0.03_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed19_maxStrain0.03_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed28_maxStrain0.04_strainStep0.0001/',
#  '../../hoomd_test/final_data/constPhi1.1_N10000_seed29_maxStrain0.04_strainStep0.0001/']

# %%
dir = dirs[39]
tmp = glob.glob(dir+"quasi/*")
df = pd.read_csv(dir+'log.dat', delimiter='\t')
traj = dir+'traj.gsd'
df = df.iloc[19:len(df.index)//4:10,:]
tmp2 = gsd.fl.open(name=traj, mode='rb')
print(tmp2.nframes)
frames = tmp2.nframes
tmp2.close()
df.pressure.plot()
for i in [0,-1]:
    a = np.load(tmp[i])
    print(tmp[i])
    t2 = a["filt_vecs"]
    print(a['evals'])
    olap = particle_overlap_matrix(t2)
    plt.figure()
    plt.matshow(olap)
    plt.title(np.mean(olap))
    
t3s = np.array([int(t.split('/')[-1].replace('.npz','')) for t in tmp])
m = np.max(t3s)/2
a = t3s[t3s > m]
b = t3s[t3s < m]
for a1 in a:
    pass

for b1 in b:
    pass
# Out:
# 48001
# ../../hoomd_test/final_data/constPhi1.1_N10000_seed17_maxStrain0.03_strainStep0.0001/quasi/0.npz
# [-1.68994302e-03 -1.68269658e-03 -1.66285870e-03 -1.21789428e-03
#  -1.20959324e-03 -1.19291548e-03 -1.18585218e-03 -1.18058100e-03
#  -1.16624988e-03 -1.15767156e-03 -1.14429719e-03 -9.77399543e-04
#  -9.59010049e-04 -9.32450391e-04 -9.31662169e-04 -8.50714779e-04
#  -8.47287617e-04 -8.41640205e-04 -8.35414559e-04 -4.80931876e-04
#  -4.75538506e-04 -4.71222646e-04 -4.61142967e-04 -2.43411447e-04
#  -2.38928132e-04 -2.37683154e-04 -2.35359234e-04 -7.90042352e-10
#  -1.66978162e-18  2.80170364e-18]
# ../../hoomd_test/final_data/constPhi1.1_N10000_seed17_maxStrain0.03_strainStep0.0001/quasi/48000.npz
# [-1.70005470e-03 -1.68639603e-03 -1.67478704e-03 -1.22506666e-03
#  -1.21370102e-03 -1.21164070e-03 -1.20119685e-03 -1.19699986e-03
#  -1.18283733e-03 -1.16922444e-03 -1.14446224e-03 -9.75339967e-04
#  -9.54864939e-04 -9.51718937e-04 -9.27584115e-04 -8.55048003e-04
#  -8.51160853e-04 -8.44270901e-04 -8.42279257e-04 -4.86786707e-04
#  -4.82882304e-04 -4.74260048e-04 -4.70566206e-04 -2.44663854e-04
#  -2.40597186e-04 -2.38434208e-04 -2.33173256e-04  1.93080334e-18
#   2.94380875e-18  1.41586729e-11]

# %%
a = np.load(tmp[0])

# %%
a.files
# Out:
# ['filt_vecs', 'evecs', 'evals']

# %%
t2 = a["filt_vecs"]

# %%
t2.dtype
# Out:
# dtype('float64')

# %%
olap = overlap_matrix(t2)

# %%
len(tmp)
# Out:
# 141

# %%
for i in np.arange(10):
    a = np.load(tmp[i])
    t2 = a["filt_vecs"]
    olap = overlap_matrix(t2)
    plt.figure()
    plt.matshow(olap)
    plt.title(np.mean(olap))

# %%
np.mean(olap)
# Out:
# 0.4806900965878027

# %%
plt.matshow(olap)

# %%
np.mean(olap)
# Out:
# 0.2957815518866284
